# %%
import pandas as pd

# %% [markdown]
# ### Disease association

# %%
df = pd.read_parquet('data/drug_warning/part-00000-1c91de83-c9dd-4eb8-a0ec-b07786a0c162-c000.snappy.parquet')

# %%
df["toxicityClass"].value_counts()
# Out:
# toxicityClass
# hepatotoxicity               196
# cardiotoxicity               174
# neurotoxicity                127
# carcinogenicity               97
# misuse                        96
# hematological toxicity        84
# vascular toxicity             79
# teratogenicity                73
# dermatological toxicity       69
# gastrointestinal toxicity     69
# psychiatric toxicity          69
# respiratory toxicity          66
# immune system toxicity        66
# infectious disease            45
# nephrotoxicity                43
# metabolic toxicity            22
# musculoskeletal toxicity      13
# occular toxicity               6
# Name: count, dtype: int64
